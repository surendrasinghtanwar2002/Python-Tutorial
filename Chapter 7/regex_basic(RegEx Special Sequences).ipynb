# %%
                    ## A special sequence is a \ followed by one of the characters in the list below, and has a special meaning ##


# Instead of using character class we can use the special character to find the #

import re

# %%
with open("E:\\Python-Tutorial\\Chapter_7\\practise_text.txt", "r",encoding="utf-8") as file:
    # Read the contents of the file
    common_data = file.read()

# %%
pattern1 = r"[\d]"                                      # Only matches integer or number and it will find the numerical value only

result1 = re.finditer(pattern1,common_data)

##Calling the for loop to iterate all the data from the object
for output1 in result1:
    print(f"Output index_Starting_value:-> {output1.start()} grouping:-> {output1.group()}" )
# Out:
# Output index_Starting_value:-> 140 grouping:-> 1
# Output index_Starting_value:-> 141 grouping:-> 2
# Output index_Starting_value:-> 142 grouping:-> 3
# Output index_Starting_value:-> 406 grouping:-> 1
# Output index_Starting_value:-> 407 grouping:-> 2
# Output index_Starting_value:-> 408 grouping:-> 3
# Output index_Starting_value:-> 490 grouping:-> 5
# Output index_Starting_value:-> 491 grouping:-> 5
# Output index_Starting_value:-> 492 grouping:-> 5
# Output index_Starting_value:-> 495 grouping:-> 1
# Output index_Starting_value:-> 496 grouping:-> 2
# Output index_Starting_value:-> 497 grouping:-> 3
# Output index_Starting_value:-> 499 grouping:-> 4
# Output index_Starting_value:-> 500 grouping:-> 5
# Output index_Starting_value:-> 501 grouping:-> 6
# Output index_Starting_value:-> 502 grouping:-> 7
# Output index_Starting_value:-> 506 grouping:-> 5
# Output index_Starting_value:-> 507 grouping:-> 5
# Output index_Starting_value:-> 508 grouping:-> 5
# ...

# %%
pattern2 = r"\D"                        #Return a match where the string does not contains digit

result2 = re.finditer(pattern2,common_data)

##Calling the for loop
for output2 in result2:
    print(f"Starting index value:-> {output2.start()} and grouping:-> {output2.group()}")
# Out:
# Starting index value:-> 0 and grouping:-> H
# Starting index value:-> 1 and grouping:-> e
# Starting index value:-> 2 and grouping:-> l
# Starting index value:-> 3 and grouping:-> l
# Starting index value:-> 4 and grouping:-> o
# Starting index value:-> 5 and grouping:-> ,
# Starting index value:-> 6 and grouping:->
# Starting index value:-> 7 and grouping:-> W
# Starting index value:-> 8 and grouping:-> o
# Starting index value:-> 9 and grouping:-> r
# Starting index value:-> 10 and grouping:-> l
# Starting index value:-> 11 and grouping:-> d
# Starting index value:-> 12 and grouping:-> !
# Starting index value:-> 13 and grouping:->
# Starting index value:-> 14 and grouping:-> W
# Starting index value:-> 15 and grouping:-> e
# Starting index value:-> 16 and grouping:-> l
# Starting index value:-> 17 and grouping:-> c
# Starting index value:-> 18 and grouping:-> o
# Starting index value:-> 19 and grouping:-> m
# Starting index value:-> 20 and grouping:-> e
# ...

# %%
pattern3 = r"\w"                                    ## It will matches any word-character (alphanumeric plus underscore) but not include special symbol ##

result3 = re.finditer(pattern3,common_data)



##Calling the for loop
for output3 in result3:
    print(f"Starting index:-> {output3.start()} Ending index:-> {output3.end()} Grouping:-> {output3.group()}")
# Out:
# Starting index:-> 0 Ending index:-> 1 Grouping:-> H
# Starting index:-> 1 Ending index:-> 2 Grouping:-> e
# Starting index:-> 2 Ending index:-> 3 Grouping:-> l
# Starting index:-> 3 Ending index:-> 4 Grouping:-> l
# Starting index:-> 4 Ending index:-> 5 Grouping:-> o
# Starting index:-> 7 Ending index:-> 8 Grouping:-> W
# Starting index:-> 8 Ending index:-> 9 Grouping:-> o
# Starting index:-> 9 Ending index:-> 10 Grouping:-> r
# Starting index:-> 10 Ending index:-> 11 Grouping:-> l
# Starting index:-> 11 Ending index:-> 12 Grouping:-> d
# Starting index:-> 14 Ending index:-> 15 Grouping:-> W
# Starting index:-> 15 Ending index:-> 16 Grouping:-> e
# Starting index:-> 16 Ending index:-> 17 Grouping:-> l
# Starting index:-> 17 Ending index:-> 18 Grouping:-> c
# Starting index:-> 18 Ending index:-> 19 Grouping:-> o
# Starting index:-> 19 Ending index:-> 20 Grouping:-> m
# Starting index:-> 20 Ending index:-> 21 Grouping:-> e
# Starting index:-> 22 Ending index:-> 23 Grouping:-> t
# ...

# %%
pattern4 = r"\W"                ##Matches any non-word Characters

result4 = re.finditer(pattern4,common_data)

##Calling the for loop 
for output4 in result4:
    print(f"Starting index value {output4.start()} Ending index value {output4.end()} Grouping value {output4.group()} ")
# Out:
# Starting index value 5 Ending index value 6 Grouping value ,
# Starting index value 6 Ending index value 7 Grouping value
# Starting index value 12 Ending index value 13 Grouping value !
# Starting index value 13 Ending index value 14 Grouping value
# Starting index value 21 Ending index value 22 Grouping value
# Starting index value 24 Ending index value 25 Grouping value
# Starting index value 28 Ending index value 29 Grouping value
# Starting index value 34 Ending index value 35 Grouping value
# Starting index value 42 Ending index value 43 Grouping value
# Starting index value 49 Ending index value 50 Grouping value .
# Starting index value 50 Ending index value 51 Grouping value
# Starting index value 51 Ending index value 52 Grouping value
#
# Starting index value 52 Ending index value 53 Grouping value
#
# Starting index value 57 Ending index value 58 Grouping value
# Starting index value 61 Ending index value 62 Grouping value
# ...

# %%
pattern5 = r"\s"                ##Matches any whitespaces characters (spaces,tabs,newlines,etc.)

result5 = re.finditer(pattern5,common_data)

##Calling the for loop
for output5 in result5:
    print(f"Staring index value {output5.start()} Ending index value {output5.end()} Grouping........-> {output5.group()}")
# Out:
# Staring index value 6 Ending index value 7 Grouping........->
# Staring index value 13 Ending index value 14 Grouping........->
# Staring index value 21 Ending index value 22 Grouping........->
# Staring index value 24 Ending index value 25 Grouping........->
# Staring index value 28 Ending index value 29 Grouping........->
# Staring index value 34 Ending index value 35 Grouping........->
# Staring index value 42 Ending index value 43 Grouping........->
# Staring index value 50 Ending index value 51 Grouping........->
# Staring index value 51 Ending index value 52 Grouping........->
#
# Staring index value 52 Ending index value 53 Grouping........->
#
# Staring index value 57 Ending index value 58 Grouping........->
# Staring index value 61 Ending index value 62 Grouping........->
# Staring index value 66 Ending index value 67 Grouping........->
# Staring index value 72 Ending index value 73 Grouping........->
# Staring index value 83 Ending index value 84 Grouping........->
#
# ...

# %%
pattern6 = r"\S"               ##Matches any non whitespaces characters

result6 = re.finditer(pattern6,common_data)

##Calling the for loop
for output6 in result6:
    print(f"Starting index value {output6.start()} Ending index value {output6.end()} Grouping {output6.group()}")
# Out:
# Starting index value 0 Ending index value 1 Grouping H
# Starting index value 1 Ending index value 2 Grouping e
# Starting index value 2 Ending index value 3 Grouping l
# Starting index value 3 Ending index value 4 Grouping l
# Starting index value 4 Ending index value 5 Grouping o
# Starting index value 5 Ending index value 6 Grouping ,
# Starting index value 7 Ending index value 8 Grouping W
# Starting index value 8 Ending index value 9 Grouping o
# Starting index value 9 Ending index value 10 Grouping r
# Starting index value 10 Ending index value 11 Grouping l
# Starting index value 11 Ending index value 12 Grouping d
# Starting index value 12 Ending index value 13 Grouping !
# Starting index value 14 Ending index value 15 Grouping W
# Starting index value 15 Ending index value 16 Grouping e
# Starting index value 16 Ending index value 17 Grouping l
# Starting index value 17 Ending index value 18 Grouping c
# Starting index value 18 Ending index value 19 Grouping o
# ...

# %%
pattern7 = r'\bsurendra'                            ##Matches a word boundary 

result7 = re.findall(pattern7,common_data)

if result7:
    print(f"We have found the pattern in the string {result7}")

else:
    print(f"We have not found any pattern in the string {result7}")
# Out:
# We have found the pattern in the string ['surendra']

# %%
pattern8 = r"\AHello,"                          ##It will find that the string is being started with specific string or not

result8 = re.finditer(pattern8,common_data)

##Calling the for loop
for output8 in result8:
    print(f"Starting index value {output8.start()} Ending index value {output8.end()} Grouping value {output8.group()}")
# Out:
# Starting index value 0 Ending index value 6 Grouping value Hello,

# %%
pattern9 = r"WORLD\Z"                       ##It will find that the string is being ended with specific string or not

common_data1 = "My name is Surendra Singh Tanwar WORLD"
result9 = re.finditer(pattern9,common_data1)

##Calling the for loop
for output9 in result9:
    print(f"Starting index value {output9.start()} Ending index value {output9.end()} Grouping value {output9.group()}")
# Out:
# Starting index value 33 Ending index value 38 Grouping value WORLD
